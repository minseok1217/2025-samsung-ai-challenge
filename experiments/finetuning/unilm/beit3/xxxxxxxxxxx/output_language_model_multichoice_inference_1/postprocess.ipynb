# %%
import pandas as pd

csv_path = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_language_model_tf_inference_1/eval_results.csv"

# %%
data = pd.read_csv(csv_path)
data.head()
# Out:
#        true     false
# 0 -3.755955 -2.611650
# 1 -1.959260 -3.704938
# 2 -2.768212 -2.614398
# 3 -3.086660 -1.620512
# 4  0.753139 -3.142226

# %%
type(data[0])
# Out:
# numpy.float64

# %%
index = []

for i in range(0, len(data), 4):
    data_row = data.iloc[i:i+4]
    print(data_row)
    max_index = data_row.idxmax() - 4*(i // 4)
    if max_index == 0:
        index.append('A')
    elif max_index == 1:
        index.append('B')
    elif max_index == 2:
        index.append('C')
    elif max_index == 3:
        index.append('D')
# Out:
# 0   -3.755955
# 1   -1.959260
# 2   -2.768212
# 3   -3.086660
# Name: true, dtype: float64
# 4    0.753139
# 5   -2.499530
# 6   -2.163041
# 7   -2.309983
# Name: true, dtype: float64
# 8    -4.260915
# 9    -0.216920
# 10   -2.181825
# 11   -3.043625
# Name: true, dtype: float64
# 12   -1.026702
# 13   -3.275700
# 14    0.768946
# 15   -1.563225
# Name: true, dtype: float64
# 16   -2.126130
# 17   -1.031862
# 18   -2.571592
# 19   -1.971573
# Name: true, dtype: float64
# 20   -2.293915
# 21   -2.290210
# 22    0.570892
# 23   -0.690412
# Name: true, dtype: float64
# 24   -1.687557
# 25    0.388919
# 26   -0.972338
# 27   -2.677710
# Name: true, dtype: float64
# 28   -2.304226
# 29   -2.718024
# 30   -4.055540
# 31   -0.534765
# Name: true, dtype: float64
# 32   -0.588741
# 33   -2.093996
# 34   -1.615969
# 35   -0.998591
# Name: true, dtype: float64
# 36   -3.309195
# 37   -3.018559
# 38   -3.369260
# 39   -3.565519
# Name: true, dtype: float64
# 40   -2.523742
# 41   -0.852953
# ...

# %%
index
# Out:
# ['B',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'B',
#  'D',
#  'A',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'A',
#  'D',
#  'B',
#  'A',
#  'B',
#  'C',
#  'A',
#  'C',
#  'B',
#  'C',
#  'C',
#  'A',
#  'A',
#  'A',
#  'D',
#  'C',
#  'B',
#  'A',
#  'C',
#  'B',
#  'D',
#  'C',
#  'B',
#  'B',
#  'D',
#  'D',
#  'B',
#  'A',
#  'B',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'C',
#  'D',
#  'A',
#  'B',
#  'C',
#  'A',
#  'D',
#  'C',
#  'A',
#  'B',
#  'D',
#  'C',
#  'D',
#  'A',
#  'C',
#  'A',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'B',
#  'D',
#  'B',
#  'D',
#  'A',
#  'D',
#  'B',
#  'A',
#  'B',
#  'D',
#  'A',
#  'D',
#  'C',
#  'B',
#  'A',
#  'A',
#  'A',
#  'C',
#  'B',
#  'D',
#  'A',
#  'C',
#  'A',
#  'B',
#  'B',
#  'B',
#  'C',
#  'D',
#  'A',
#  'C',
#  'A',
#  'B',
#  'C',
#  'D',
#  'D',
#  'C',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'C',
#  'B',
#  'B',
# ...

# %%
# make csv file
output_df = pd.DataFrame()
output_df['ID'] = [f'TEST_{i:03d}' for i in range(0, len(index))]
output_df['answer'] = index


# output_df['max']

# %%
# save to csv
output_df.to_csv('/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_language_model_tf_inference_1/language_modeling_tf.csv', index=False)
