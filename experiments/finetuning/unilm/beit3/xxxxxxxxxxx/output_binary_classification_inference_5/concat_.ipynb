# %%
import pandas as pd

# %%
csv_1 = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_binary_classification_inference_5/binary_classification_4epoch_2.csv"
csv_2 = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/data/data_2/submission/submission_averaged_5_5.csv"

# %%
# open csv
df1 = pd.read_csv(csv_1)
df2 = pd.read_csv(csv_2)
# merge csv
df_merged = pd.merge(df1, df2, on="ID", how="outer")

# %%
df_merged[:30]
# Out:
#           ID answer_x answer_y
# 0   TEST_000        B        B
# 1   TEST_001        C        A
# 2   TEST_002        B        B
# 3   TEST_003        B        C
# 4   TEST_004        C        B
# 5   TEST_005        C        C
# 6   TEST_006        A        B
# 7   TEST_007        D        D
# 8   TEST_008        B        D
# 9   TEST_009        A        A
# 10  TEST_010        A        B
# 11  TEST_011        C        B
# 12  TEST_012        C        B
# 13  TEST_013        B        C
# 14  TEST_014        D        D
# 15  TEST_015        A        B
# 16  TEST_016        C        B
# 17  TEST_017        A        A
# 18  TEST_018        A        C
# 19  TEST_019        B        C
# 20  TEST_020        B        C
# 21  TEST_021        C        C
# 22  TEST_022        C        A
# 23  TEST_023        B        A
# 24  TEST_024        B        A
# 25  TEST_025        B        A
# 26  TEST_026        C        B
# 27  TEST_027        B        C
# 28  TEST_028        C        A
# ...
