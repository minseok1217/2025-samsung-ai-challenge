# %%
import pandas as pd

csv_path = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_language_model_multichoice_inference_3_batch_64/eval_results.csv"

# %%
data = pd.read_csv(csv_path)

# %%
data
# Out:
#              A          B          C          D
# 0     2.830629   6.395661   3.486344   6.341754
# 1     9.225514  -6.970730  -1.595700  -6.293957
# 2    -2.915595   8.115647   0.154806   4.927797
# 3    58.938423  51.484531  51.339363  48.613911
# 4    36.922947  29.044060  28.246946  27.467514
# ..         ...        ...        ...        ...
# 847   3.991609   3.616007   3.747742   2.421844
# 848  24.325058  24.724531  27.091387  29.326805
# 849  -1.070941   6.049280  -4.060775   0.550869
# 850   9.602516  11.440001  15.642689  14.622804
# 851  -1.751634   1.196945  -2.625050   6.880183
#
# [852 rows x 4 columns]

# %%
max_index = []
for i in range(len(data)):
    max_index.append(data.iloc[i, 1:].idxmax())

max_index
# Out:
# ['B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'D',
#  'B',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'B',
#  'D',
#  'B',
#  'C',
#  'D',
#  'C',
#  'D',
#  'C',
#  'C',
#  'B',
#  'D',
#  'D',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'B',
#  'B',
#  'D',
#  'C',
#  'C',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'C',
#  'D',
#  'C',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'B',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'D',
#  'C',
#  'B',
#  'D',
#  'B',
#  'D',
#  'D',
#  'D',
#  'C',
#  'D',
#  'B',
#  'D',
#  'D',
#  'D',
#  'C',
#  'B',
#  'D',
#  'D',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'B',
#  'D',
#  'B',
#  'D',
#  'C',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
# ...

# %%
output_csv = pd.DataFrame()
output_csv['ID'] = [f'TEST_{i:03}' for i in range(len(max_index))]
output_csv['answer'] = max_index

output_csv
# Out:
#            ID answer
# 0    TEST_000      B
# 1    TEST_001      C
# 2    TEST_002      B
# 3    TEST_003      B
# 4    TEST_004      B
# ..        ...    ...
# 847  TEST_847      C
# 848  TEST_848      D
# 849  TEST_849      B
# 850  TEST_850      C
# 851  TEST_851      D
#
# [852 rows x 2 columns]

# %%
output_csv.to_csv('/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_language_model_multichoice_inference_3_batch_64/language_model_multichoice_5.csv', index=False)
