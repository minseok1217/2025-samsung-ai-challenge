# %%
import pandas as pd
csv_path = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_binary_classification_inference_3/eval_results.csv"

# %%
data = pd.read_csv(csv_path)

# %%
logit = data["logit"].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /data/2_data_server/cv-07/anaconda3/envs/beit3_new/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'logit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ...

# %%
submission = []
for i in range(0, len(logit),4):
    argmax = logit[i:i+4].argmax()
    if argmax == 0:
        answer = "A"
    elif argmax == 1:
        answer = "B"
    elif argmax == 2:
        answer = "C"
    elif argmax == 3:
        answer = "D"

    submission.append({
        "ID": f'TEST_{i//4:03d}',
        "answer": answer
    })

# %%
submission
# Out:
# [{'ID': 'TEST_000', 'answer': 'B'},
#  {'ID': 'TEST_001', 'answer': 'C'},
#  {'ID': 'TEST_002', 'answer': 'B'},
#  {'ID': 'TEST_003', 'answer': 'B'},
#  {'ID': 'TEST_004', 'answer': 'C'},
#  {'ID': 'TEST_005', 'answer': 'C'},
#  {'ID': 'TEST_006', 'answer': 'B'},
#  {'ID': 'TEST_007', 'answer': 'D'},
#  {'ID': 'TEST_008', 'answer': 'B'},
#  {'ID': 'TEST_009', 'answer': 'A'},
#  {'ID': 'TEST_010', 'answer': 'A'},
#  {'ID': 'TEST_011', 'answer': 'C'},
#  {'ID': 'TEST_012', 'answer': 'C'},
#  {'ID': 'TEST_013', 'answer': 'B'},
#  {'ID': 'TEST_014', 'answer': 'D'},
#  {'ID': 'TEST_015', 'answer': 'A'},
#  {'ID': 'TEST_016', 'answer': 'B'},
#  {'ID': 'TEST_017', 'answer': 'A'},
#  {'ID': 'TEST_018', 'answer': 'A'},
#  {'ID': 'TEST_019', 'answer': 'B'},
#  {'ID': 'TEST_020', 'answer': 'B'},
#  {'ID': 'TEST_021', 'answer': 'C'},
#  {'ID': 'TEST_022', 'answer': 'C'},
#  {'ID': 'TEST_023', 'answer': 'B'},
#  {'ID': 'TEST_024', 'answer': 'B'},
#  {'ID': 'TEST_025', 'answer': 'B'},
# ...

# %%
# save submission
submission_path = "/data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_binary_classification_inference_3/binary_classification_4epoch_2.csv"
submission_df = pd.DataFrame(submission)
submission_df.to_csv(submission_path, index=False)
print(f"Submission saved to {submission_path}")
# Out:
# Submission saved to /data/2_data_server/cv-07/dice/2025_samsung_challenge/finetuning/unilm/beit3/output_binary_classification_inference_3/binary_classification_4epoch_2.csv
